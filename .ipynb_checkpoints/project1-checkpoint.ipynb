# %%
import numpy as np
import pandas as pd
import pprint
import matplotlib as plt
import datetime

# %%
data_url = "https://raw.githubusercontent.com/datsoftlyngby/soft2019spring-ai/master/projects/project1/users.json"
data = pd.read_json(data_url, date_unit="ms")

# %%
now = datetime.datetime.now()
data["days_since_created"] = np.nan

def get_time_since_creation(created):
    try:
        i = int(created)
        create_date = datetime.datetime.fromtimestamp(i)
        return (now - create_date).days
    except ValueError:
        print('Not an integer')
        print(created)

data['days_since_created'] = data.apply(lambda row: get_time_since_creation(row['created']), axis=1)
# Out:
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan

# %%
#pprint.pprint(data)
#now = datetime.datetime.now()
data.plot.scatter(x="days_since_created", y="karma")

# %% [markdown]
# We choose the linear regression model. Linear was because that the general data values seemed to rise linearly between the x & y axis. We choose regression because we want to predict a y value by kmowing the x value.

# %%
import sklearn.linear_model
model = sklearn.linear_model.LinearRegression()
model.fit(data["days_since_created"], data["karma"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-7e31a101513e> in <module>()
#       1 import sklearn.linear_model
#       2 model = sklearn.linear_model.LinearRegression()
# ----> 3 model.fit(data["days_since_created"], data["karma"])
#
# /home/ras/.local/lib/python3.6/site-packages/sklearn/linear_model/base.py in fit(self, X, y, sample_weight)
#     456         n_jobs_ = self.n_jobs
#     457         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 458                          y_numeric=True, multi_output=True)
#     459
#     460         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# /home/ras/.local/lib/python3.6/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     754                     ensure_min_features=ensure_min_features,
#     755                     warn_on_dtype=warn_on_dtype,
# --> 756                     estimator=estimator)
#     757     if multi_output:
#     758         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# /home/ras/.local/lib/python3.6/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     550                     "Reshape your data either using array.reshape(-1, 1) if "
#     551                     "your data has a single feature or array.reshape(1, -1) "
# --> 552                     "if it contains a single sample.".format(array))
#     553
#     554         # in the future np.flexible dtypes will be handled like object dtypes
#
# ValueError: Expected 2D array, got 1D array instead:
# array=[ 465. 2603. 1055. ... 1888. 1608.  728.].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.
