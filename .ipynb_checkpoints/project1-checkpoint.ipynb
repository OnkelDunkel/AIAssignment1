# %%
import numpy as np
import pandas as pd
import pprint
import matplotlib as plt
import datetime

# %%
data_url = "https://raw.githubusercontent.com/datsoftlyngby/soft2019spring-ai/master/projects/project1/users.json"
data = pd.read_json(data_url, date_unit="ms")

# %%
now = datetime.datetime.now()
for index, row in data.iterrows():
    try:
        i = int(row.created)
        #create_date = datetime.datetime.fromtimestamp(i)
        #row.time_since_created = now - create_date
    except ValueError:
        print('Not an integer')
        print(row.created)
# Out:
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# ...

# %%
#pprint.pprint(data)
#now = datetime.datetime.now()
data.plot.scatter(x="time_since_created", y="karma")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /home/ras/.local/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2655             try:
# -> 2656                 return self._engine.get_loc(key)
#    2657             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'time_since_created'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-437f548d4683> in <module>()
# ...

# %%
# Out:
# 1550492606
