# %%
import numpy as np
import pandas as pd
import pprint
import matplotlib as plt
import datetime

# %%
data_url = "https://raw.githubusercontent.com/datsoftlyngby/soft2019spring-ai/master/projects/project1/users.json"
data = pd.read_json(data_url, date_unit="ms")

# %%
now = datetime.datetime.now()
data["days_since_created"] = np.nan

def get_time_since_creation(created):
    try:
        i = int(created)
        create_date = datetime.datetime.fromtimestamp(i)
        return (now - create_date).days
    except ValueError:
        print('Not an integer')
        print(created)

data['days_since_created'] = data.apply(lambda row: get_time_since_creation(row['created']), axis=1)
# Out:
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan
# Not an integer
# nan

# %%
#pprint.pprint(data)
#now = datetime.datetime.now()
data.plot.scatter(x="days_since_created", y="karma")
# Out:
#                                                   about       created error  \
# 0                                                   NaN  1.510266e+09   NaN
# 1                             Ruby, Open Source, Devops  1.325548e+09   NaN
# 2                                                   NaN  1.459331e+09   NaN
# 3     [ my public key: https:&#x2F;&#x2F;keybase.io&...  1.379698e+09   NaN
# 4     Email: ejstronge@gmail.com\nGithub: https:&#x2...  1.355740e+09   NaN
# 5                                                   NaN  1.276201e+09   NaN
# 6                                                   NaN  1.382222e+09   NaN
# 7                                                   NaN  1.330724e+09   NaN
# 8                                                   NaN  1.475393e+09   NaN
# 9                            github.com&#x2F;allcentury  1.389810e+09   NaN
# 10              metaleap.net | github.com&#x2F;metaleap  1.200513e+09   NaN
# 11    Do you want to talk?\ncj2k17 &lt;ät&gt; t-onli...  1.375380e+09   NaN
# 12                                                  NaN  1.459331e+09   NaN
# 13    http:&#x2F;&#x2F;mamota.net<p>hnchat:qd9GpaNW9...  1.311660e+09   NaN
# 14                                                  NaN  1.347719e+09   NaN
# 15                                                  NaN  1.301509e+09   NaN
# 16                                                  NaN  1.380611e+09   NaN
# 17                                                  NaN  1.466756e+09   NaN
# 18                                                  NaN  1.284811e+09   NaN
# 19    founder&#x2F;owner - https:&#x2F;&#x2F;river.r...  1.467097e+09   NaN
# 20    Hardy couldnt have been more wrong about the i...  1.383033e+09   NaN
# 21                                                  NaN  1.476843e+09   NaN
# 22                                                  NaN  1.459331e+09   NaN
# 23                                                  NaN  1.439844e+09   NaN
# 24                                                  NaN  1.404369e+09   NaN
# 25                                                  NaN  1.375960e+09   NaN
# 26                                                  NaN  1.474644e+09   NaN
# 27                     http:&#x2F;&#x2F;geocar.sdf1.org  1.210171e+09   NaN
# 28                                                  NaN  1.427274e+09   NaN
# 29                                                  NaN  1.427274e+09   NaN
# ...                                                 ...           ...   ...
# 9401                                                NaN  1.435324e+09   NaN
# 9402                                                NaN  1.348241e+09   NaN
# 9403  Seasoned software developer, proficient in Pyt...  1.205327e+09   NaN
# 9404                                                NaN  1.443130e+09   NaN
# 9405                  http:&#x2F;&#x2F;blog.dispatch.no  1.464074e+09   NaN
# 9406                                                NaN  1.487229e+09   NaN
# 9407                                                NaN  1.361373e+09   NaN
# 9408  Studying mathematics - from the basics to the ...  1.334118e+09   NaN
# 9409  QA engineer on the QAM modulator and multiplex...  1.403204e+09   NaN
# 9410  I am a teacher and tinkerer.<p>http:&#x2F;&#x2...  1.340483e+09   NaN
# 9411  https:&#x2F;&#x2F;ewan.im&#x2F;\nEmail: ewan a...  1.280917e+09   NaN
# 9412                                                NaN  1.380203e+09   NaN
# 9413  Website: https:&#x2F;&#x2F;pierre.world&#x2F;<...  1.291498e+09   NaN
# 9414                                                NaN  1.409183e+09   NaN
# 9415  viraptor _monkey_symbol_ gmail _full_stop_ com...  1.234121e+09   NaN
# 9416  viraptor _monkey_symbol_ gmail _full_stop_ com...  1.234121e+09   NaN
# 9417                                                NaN  1.403193e+09   NaN
# 9418                                                NaN  1.432201e+09   NaN
# 9419                                                NaN  1.287141e+09   NaN
# 9420  http:&#x2F;&#x2F;blog.metaobject.com&#x2F;<p>h...  1.333104e+09   NaN
# 9421  I run a bootstrapped B2C SaaS. Mostly a lurker...  1.258733e+09   NaN
# 9422                                                NaN  1.347807e+09   NaN
# 9423                                                NaN  1.375279e+09   NaN
# 9424                                                NaN  1.498829e+09   NaN
# 9425                                                NaN  1.506081e+09   NaN
# 9426                                                NaN  1.501832e+09   NaN
# 9427                                                NaN  1.483074e+09   NaN
# 9428                                                NaN  1.387363e+09   NaN
# 9429                                                NaN  1.411489e+09   NaN
# 9430                                                NaN  1.487598e+09   NaN
#
#                   id    karma  submitted  days_since_created
# 0         gcgggfxsdg     -1.0          5               465.0
# 1            sheerun    102.0         51              2603.0
# 2           keypress     79.0         70              1055.0
# 3            pyprism   1356.0        114              1976.0
# 4          ejstronge    460.0        144              2254.0
# 5          akira2501    880.0        304              3174.0
# 6       matchagaucho    412.0        228              1947.0
# 7            bberrry    273.0         49              2543.0
# 8       sharjeelsidd      1.0          1               869.0
# 9         allcentury     56.0         41              1859.0
# 10           dualogy   2796.0       1389              4050.0
# 11             cJ0th   1211.0        525              2026.0
# 12          keypress     79.0         70              1055.0
# 13           fredley   3861.0        670              2764.0
# 14          goldfeld   1380.0        679              2346.0
# 15          delsarto    480.0         86              2881.0
# 16             neals   1449.0        367              1966.0
# 17             petre    709.0        802               969.0
# 18              cjg_    202.0         91              3075.0
# 19           kierenj     87.0         44               965.0
# 20         goldenkey   1343.0       1366              1938.0
# 21         quicklime    126.0         33               852.0
# 22          keypress     79.0         70              1055.0
# 23     markarichards      6.0          3              1280.0
# 24           xorcist   2659.0       1472              1691.0
# 25         megaman22   1182.0        330              2020.0
# 26     tommywilliams     79.0         12               877.0
# 27            geocar   2201.0        864              3938.0
# 28           geomark   1281.0        461              1426.0
# 29           geomark   1281.0        461              1426.0
# ...              ...      ...        ...                 ...
# 9401         vultour     96.0         75              1332.0
# 9402       scaryclam    681.0        235              2340.0
# 9403         rbanffy  49813.0      18850              3995.0
# 9404      red75prime    126.0        138              1242.0
# 9405         erikbye    486.0        330              1000.0
# 9406     sitepodmatt    353.0        164               732.0
# 9407             rtb    477.0         91              2188.0
# 9408       chris_wot  12559.0       6541              2504.0
# 9409          Yizahi    215.0        176              1704.0
# 9410       cardamomo    915.0        195              2430.0
# 9411         EwanToo   4202.0        915              3120.0
# 9412        mozumder   1547.0       1061              1970.0
# 9413         bpierre  33354.0       1721              2997.0
# 9414    burntcaramel     16.0         37              1635.0
# 9415        viraptor  14226.0       5295              3661.0
# 9416        viraptor  14226.0       5295              3661.0
# 9417         dnetesn  33581.0       4646              1704.0
# 9418  NetStrikeForce   1220.0        735              1369.0
# 9419   adrianoconnor     98.0         48              3048.0
# 9420        mpweiher  17274.0       3084              2516.0
# 9421              WA   2658.0        638              3376.0
# 9422        Cthulhu_   4241.0       2106              2345.0
# 9423     arca_vorago   3099.0       1311              2027.0
# 9424         hennsen     34.0         31               597.0
# 9425          moogie      1.0          4               514.0
# 9426           chewz    128.0         86               563.0
# 9427    laughingman2     87.0         59               780.0
# 9428          watwut   3258.0       1682              1888.0
# 9429     xyzzy_plugh    852.0        227              1608.0
# 9430           colde     92.0         18               728.0
#
# [9431 rows x 7 columns]

# %%
# Out:
# 1550492606
